# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
data= pd.read_csv("suicide_rate.csv")
data
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
for year, year_df in suicide_counts.groupby(level=0):
    # Find the country with the highest number of suicides for the year
    max_country = year_df.idxmax()[1]
    # Find the highest number of suicides for the year
    max_suicides = year_df.max()
    # Find the number of suicides for the country with the most suicides
    suicides = suicide_counts.loc[(year, max_country)]
    print(f'In {year}, the country with the most suicides was {max_country} with {suicides} suicides')
# Out:
# In 1985, the country with the most suicides was United States with 29446 suicides
# In 1986, the country with the most suicides was United States with 30892 suicides
# In 1987, the country with the most suicides was United States with 30783 suicides
# In 1988, the country with the most suicides was United States with 30388 suicides
# In 1989, the country with the most suicides was Russian Federation with 37921 suicides
# In 1990, the country with the most suicides was Russian Federation with 39028 suicides
# In 1991, the country with the most suicides was Russian Federation with 39281 suicides
# In 1992, the country with the most suicides was Russian Federation with 45923 suicides
# In 1993, the country with the most suicides was Russian Federation with 55846 suicides
# In 1994, the country with the most suicides was Russian Federation with 61420 suicides
# In 1995, the country with the most suicides was Russian Federation with 60548 suicides
# ...

# %%
counts = data.groupby(by = ["suicides_no"])["suicides_no"].count().sort_values()

# we will only consider countries with a decent number of entries.
counts.mean()
#take country i wilkl take united kingdom
#make a grapjg
# Out:
# 13.349328214971209

# %%
uk_data = data[data['country'] == 'United Kingdom']
uk_data
# Out:
#               country  year     sex          age  suicides_no  population  \
# 26476  United Kingdom  1985    male    75+ years          264     1202838
# 26477  United Kingdom  1985    male  55-74 years          915     5170113
# 26478  United Kingdom  1985    male  35-54 years         1208     6899879
# 26479  United Kingdom  1985    male  25-34 years          620     3969689
# 26480  United Kingdom  1985  female  55-74 years          678     6002096
# ...               ...   ...     ...          ...          ...         ...
# 26843  United Kingdom  2015  female  25-34 years          181     4414464
# 26844  United Kingdom  2015  female    75+ years          108     3070457
# 26845  United Kingdom  2015  female  15-24 years          104     3966564
# 26846  United Kingdom  2015  female   5-14 years            6     3663221
# 26847  United Kingdom  2015    male   5-14 years            4     3840476
#
#        suicides/100k pop        country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
years = sorted(data.year.unique())
population = []
suicides =[]
for year in sorted(years):
    population.append(uk_data[uk_data['year']==year]['population'].sum())
    suicides.append(uk_data[uk_data['year']==year]['suicides_no'].sum())

plt.subplot(2,1,1)
plt.plot(years,population)
plt.xlabel("Years")
plt.ylabel("Global Population (Billion)")
plt.grid()
plt.subplot(2,1,2)
plt.plot(years,suicides)
plt.xlabel("Years")
plt.ylabel("Suicides per Year")
plt.grid()

# %%
ukcounts = uk_data.groupby(by = ["suicides_no"])["suicides_no"].count().sort_values()
ukcounts.mean()
# Out:
# 1.414448669201521

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("suicide_rate.csv")
male = uk_data[(uk_data['sex'] == "male")]
female = uk_data[(uk_data['sex'] == "female")]
years = [year for year in np.unique(data['year'])]  # list of years to include in the plot
m_suic = []
m_pop = []
fm_suic = []
fm_pop = []
for year in years:
    m_suic.append(male[male['year'] == year]['suicides_no'].sum())
    fm_suic.append(female[female['year'] == year]['suicides_no'].sum())
    m_pop.append(male[male['year'] == year]['population'].sum())
    fm_pop.append(female[female['year'] == year]['population'].sum())

# plot population data
plt.subplot(2, 1, 1)
plt.plot(years, m_pop, color="r", label="Male")
plt.plot(years, fm_pop, color="b", label="Female")
plt.ylabel("Population globally ")
plt.legend()
plt.grid()

# plot suicides data
plt.subplot(2, 1, 2)
plt.plot(years, m_suic, color="r", label="Male")
plt.plot(years, fm_suic, color="b", label="Female")
plt.ylabel("Suicides Number")
plt.legend()
plt.grid()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("suicide_rate.csv")
npgenerations = np.unique(data['generation'])  # take all the unique values of generation column
y_pos = np.arange(len(npgenerations))
gen_suic = [data[data['generation']== gen]['suicides_no'].sum() for gen in npgenerations]  # sum over the generations
plt.barh(y_pos, gen_suic, align='center', color="b")
plt.yticks(y_pos, npgenerations)
plt.grid()

# %%
uk_data = data[data['country'] == 'United Kingdom']

# Get the unique values of the 'generation' column and the corresponding counts of suicides
npgenerations, gen_suic = np.unique(uk_data['generation'], return_counts=True)

# Create the bar plot
plt.barh(y_pos, gen_suic, align='center', color="b")
plt.yticks(y_pos, npgenerations)
plt.grid()
plt.title("Suicides by Generation in the United Kingdom")
plt.xlabel("Number of Suicides")
plt.ylabel("Generation")
plt.show()
